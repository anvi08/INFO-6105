# %% [markdown]
# Import a number of useful libraries

# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
# %matplotlib inline
import seaborn as sns;
import itertools;
##from fraction import Fractions;

# %% [markdown]
# 1 a) Professor is curious whether he has the same probability to meet a F1 driver if he goes to one of seven shows for the whole duration of the show and if 7 F1 racers go to 7 shows where each racer goes to one and only one show for 7 minutes.

# %% [markdown]
# Answer 1 a)
# The probability of the professor seeing a driver is 1 - probability of not seeing any driver which is 6/7 to the power 7 because there are 7 drivers

# %%
prob_seeing_a_driver = 1 -(6/7)**7
print("The probability of seeing a driver is " + str(prob_seeing_a_driver))
# Out:
# The probability of seeing a driver is 0.6600833229108864

# %% [markdown]
# Answer 1 b)
# The total number of outcomes

# %%
a= {b for b in prod if 'profPresent' in b}

# %%
p(a,prod)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 p(a,prod)
#
# Input In [29], in p(event, space)
#      28 if is_predicate(event):
#      29     event = such_that(...)
# ---> 30 return Fraction(len(event & space), len(space))
#
# TypeError: unsupported operand type(s) for &: 'set' and 'list'

# %%
#list=[]
for i in range(0,7):
    a=combinations(drivers,i)
    #list.append(a)

# %%
# python program to demonstrate
# unique combination of two lists
# using zip() and permutation of itertools



# import itertools package
import itertools
from itertools import permutations



# initialize lists
list_1 = ["a", "b", "c","d"]
list_2 = [1,4,9]



# create empty list to store the
# combinations
unique_combinations = []



# Getting all permutations of list_1
# with length of list_2
permut = itertools.permutations(list_1, len(list_2))



# zip() is called to pair each permutation
# and shorter list element into combination
for comb in permut:
    zipped = zip(comb, list_2)
    unique_combinations.append(list(zipped))



# printing unique_combination list
print(unique_combinations)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 33>()
#      33 for comb in permut:
#      34     zipped = zip(comb, list_2)
# ---> 35     unique_combinations.append(list(zipped))
#      39 # printing unique_combination list
#      40 print(unique_combinations)
#
# TypeError: 'list' object is not callable

# %%
shows = ["show1", "show2", "show3","show4", "show5", "show6", "show7"]
drivers = ["driver1", "driver2", "driver3","driver4", "driver5", "driver6", "driver7"]
for items in combinations(shows,drivers):
    print(items)

# %%
shows='1234567'
drivers='abcdefg'
a=list(product(shows,drivers))
lst=[]
#for show in shows:
    for driver in drivers:
        a=list(product(show,driver))
        lst.append(a)
print(prod)

# %%
shows = ["show1", "show2", "show3","show4", "show5", "show6", "show7"]
drivers = ["driver1", "driver2", "driver3","driver4", "driver5", "driver6", "driver7"]
a=[]
for show in shows:
    for driver in drivers:
        print(list(product(show,driver)))
        
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 4>()
#       4 for show in shows:
#       5     for driver in drivers:
# ----> 6         print(list(product(show,driver)))
#       8 print(a)
#
# TypeError: 'list' object is not callable

# %%
##generating all combinations of 
from itertools import product
from itertools import combinations
shows = ["show1", "show2", "show3","show4", "show5", "show6", "show7"]
drivers = ["driver1", "driver2", "driver3","driver4", "driver5", "driver6", "driver7"]
b=list(combinations(drivers,2))
b
prof = ["profPresent", "profAbsent"]
prod = set(product(shows,drivers,prof))
list=[]
for i in range(0,7):
    a=combinations(drivers,i)
    list.append(a)
    
    
    
    
    
    
#for i in prod:
 #   if i[0] == i[1]:
  #      prod.remove(i)
#print(prod)
from fractions import Fraction
def p(event, space): 
    """The probability of an event, given a sample space of equiprobable outcomes.
    event can be either a set of outcomes, or a predicate (true for outcomes in the event)."""
    if is_predicate(event):
        event = such_that(...)
    return Fraction(len(event & space), len(space))

is_predicate = callable

def such_that(predicate, collection): 
    return ...
# size of combination is set to 
#a = combinations(shows, 2)
#y = [' '.join(i) for i in a]
 
#print(y)

# %%
shows = ["show1", "show2", "show3","show4", "show5", "show6", "show7"]
drivers = ["driver1", "driver2", "driver3","driver4", "driver5", "driver6", "driver7"]

comb_list = [(s,d) for s in shows for d in drivers]
comb_list
sample_space = combinations(comb_list,7)
sample_space_list = [c for c in sample_space]
sample_space_list[:20]
len(sample_space_list)
# Out:
# 85900584

# %%
sample_space_list[:20]
# Out:
# [(('show1', 'driver1'),
#   ('show1', 'driver2'),
#   ('show1', 'driver3'),
#   ('show1', 'driver4'),
#   ('show1', 'driver5'),
#   ('show1', 'driver6'),
#   ('show1', 'driver7')),
#  (('show1', 'driver1'),
#   ('show1', 'driver2'),
#   ('show1', 'driver3'),
#   ('show1', 'driver4'),
#   ('show1', 'driver5'),
#   ('show1', 'driver6'),
#   ('show2', 'driver1')),
#  (('show1', 'driver1'),
#   ('show1', 'driver2'),
#   ('show1', 'driver3'),
#   ('show1', 'driver4'),
#   ('show1', 'driver5'),
#   ('show1', 'driver6'),
#   ('show2', 'driver2')),
#  (('show1', 'driver1'),
#   ('show1', 'driver2'),
#   ('show1', 'driver3'),
#   ('show1', 'driver4'),
#   ('show1', 'driver5'),
#   ('show1', 'driver6'),
#   ('show2', 'driver3')),
#  (('show1', 'driver1'),
#   ('show1', 'driver2'),
#   ('show1', 'driver3'),
#   ('show1', 'driver4'),
#   ('show1', 'driver5'),
#   ('show1', 'driver6'),
#   ('show2', 'driver4')),
#  (('show1', 'driver1'),
#   ('show1', 'driver2'),
#   ('show1', 'driver3'),
# ...

# %%
drivers = ['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7']
shows = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7']

# %%
def joint(A, B, C, D, E, F, G, shows, sep=''):
    """The joint distribution of two independent probability distributions.
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return {a + sep + b + sep + c + sep + e + sep + f + sep + g + sep + h +sep + i + sep+ j+ sep+k+sep+l+sep+m+sep+n+sep+o+sep+p
                    for a in A
                    for b in B
                    for c in C
                    for d in D
                    for e in E
                    for f in F
                    for g in G
                    for h in shows
                    for i in shows
                    for j in shows
                    for k in shows
                    for l in shows
                    for m in shows
                    for n in shows
                    for o in shows
                    for p in shows
           }

# %%
D1='D1'
D2='D2'
D3='D3'
D4='D4'
D5='D5'
D6='D6'
D7='D7'
len(joint(D1,D2,D3,D4,D5,D6,D7, shows, ' '))

# %%
from itertools import product
from itertools import combinations
prob2 = list(product(shows,drivers))
prob2
# Out:
# [('S1', 'D1'),
#  ('S1', 'D2'),
#  ('S1', 'D3'),
#  ('S1', 'D4'),
#  ('S1', 'D5'),
#  ('S1', 'D6'),
#  ('S1', 'D7'),
#  ('S2', 'D1'),
#  ('S2', 'D2'),
#  ('S2', 'D3'),
#  ('S2', 'D4'),
#  ('S2', 'D5'),
#  ('S2', 'D6'),
#  ('S2', 'D7'),
#  ('S3', 'D1'),
#  ('S3', 'D2'),
#  ('S3', 'D3'),
#  ('S3', 'D4'),
#  ('S3', 'D5'),
#  ('S3', 'D6'),
#  ('S3', 'D7'),
#  ('S4', 'D1'),
#  ('S4', 'D2'),
#  ('S4', 'D3'),
#  ('S4', 'D4'),
#  ('S4', 'D5'),
#  ('S4', 'D6'),
#  ('S4', 'D7'),
#  ('S5', 'D1'),
#  ('S5', 'D2'),
#  ('S5', 'D3'),
#  ('S5', 'D4'),
#  ('S5', 'D5'),
#  ('S5', 'D6'),
#  ('S5', 'D7'),
#  ('S6', 'D1'),
#  ('S6', 'D2'),
#  ('S6', 'D3'),
#  ('S6', 'D4'),
#  ('S6', 'D5'),
#  ('S6', 'D6'),
#  ('S6', 'D7'),
#  ('S7', 'D1'),
#  ('S7', 'D2'),
#  ('S7', 'D3'),
#  ('S7', 'D4'),
#  ('S7', 'D5'),
#  ('S7', 'D6'),
#  ('S7', 'D7')]

# %%
prob2=[]
for i in range(1,8):
    b=list(combinations(shows,i))
    a = list(product(b,drivers))
    prob2.append(a)
ls_drivers=sum([list(x) for x in prob2],[])
ls_drivers
# Out:
# [(('S1',), 'D1'),
#  (('S1',), 'D2'),
#  (('S1',), 'D3'),
#  (('S1',), 'D4'),
#  (('S1',), 'D5'),
#  (('S1',), 'D6'),
#  (('S1',), 'D7'),
#  (('S2',), 'D1'),
#  (('S2',), 'D2'),
#  (('S2',), 'D3'),
#  (('S2',), 'D4'),
#  (('S2',), 'D5'),
#  (('S2',), 'D6'),
#  (('S2',), 'D7'),
#  (('S3',), 'D1'),
#  (('S3',), 'D2'),
#  (('S3',), 'D3'),
#  (('S3',), 'D4'),
#  (('S3',), 'D5'),
#  (('S3',), 'D6'),
#  (('S3',), 'D7'),
#  (('S4',), 'D1'),
#  (('S4',), 'D2'),
#  (('S4',), 'D3'),
#  (('S4',), 'D4'),
#  (('S4',), 'D5'),
#  (('S4',), 'D6'),
#  (('S4',), 'D7'),
#  (('S5',), 'D1'),
#  (('S5',), 'D2'),
#  (('S5',), 'D3'),
#  (('S5',), 'D4'),
#  (('S5',), 'D5'),
#  (('S5',), 'D6'),
#  (('S5',), 'D7'),
#  (('S6',), 'D1'),
#  (('S6',), 'D2'),
#  (('S6',), 'D3'),
#  (('S6',), 'D4'),
#  (('S6',), 'D5'),
#  (('S6',), 'D6'),
#  (('S6',), 'D7'),
#  (('S7',), 'D1'),
#  (('S7',), 'D2'),
#  (('S7',), 'D3'),
#  (('S7',), 'D4'),
#  (('S7',), 'D5'),
#  (('S7',), 'D6'),
#  (('S7',), 'D7'),
# ...

# %%
b=list(combinations(drivers,3))
prob2 = list(product(b,shows))
len(prob2)
# Out:
# 245

# %%
b=list(combinations(drivers,4))
prob2 = list(product(b,shows))
len(prob2)
# Out:
# 245

# %%
b=list(combinations(drivers,5))
prob2 = list(product(b,shows))
len(prob2)
# Out:
# 147

# %%
b=list(combinations(drivers,6))
prob2 = list(product(b,shows))
len(prob2)
# Out:
# 49

# %%
b=list(combinations(drivers,7))
prob2 = list(product(b,shows))
len(prob2)
# Out:
# 7

# %%
prob2 = list(product(["driver1"],shows))
prob2
# Out:
# [('driver1', 'S1'),
#  ('driver1', 'S2'),
#  ('driver1', 'S3'),
#  ('driver1', 'S4'),
#  ('driver1', 'S5'),
#  ('driver1', 'S6'),
#  ('driver1', 'S7')]

# %%
prob2 = list(product(drivers,shows))
prob2
# Out:
# [('D1', 'S1'),
#  ('D1', 'S2'),
#  ('D1', 'S3'),
#  ('D1', 'S4'),
#  ('D1', 'S5'),
#  ('D1', 'S6'),
#  ('D1', 'S7'),
#  ('D2', 'S1'),
#  ('D2', 'S2'),
#  ('D2', 'S3'),
#  ('D2', 'S4'),
#  ('D2', 'S5'),
#  ('D2', 'S6'),
#  ('D2', 'S7'),
#  ('D3', 'S1'),
#  ('D3', 'S2'),
#  ('D3', 'S3'),
#  ('D3', 'S4'),
#  ('D3', 'S5'),
#  ('D3', 'S6'),
#  ('D3', 'S7'),
#  ('D4', 'S1'),
#  ('D4', 'S2'),
#  ('D4', 'S3'),
#  ('D4', 'S4'),
#  ('D4', 'S5'),
#  ('D4', 'S6'),
#  ('D4', 'S7'),
#  ('D5', 'S1'),
#  ('D5', 'S2'),
#  ('D5', 'S3'),
#  ('D5', 'S4'),
#  ('D5', 'S5'),
#  ('D5', 'S6'),
#  ('D5', 'S7'),
#  ('D6', 'S1'),
#  ('D6', 'S2'),
#  ('D6', 'S3'),
#  ('D6', 'S4'),
#  ('D6', 'S5'),
#  ('D6', 'S6'),
#  ('D6', 'S7'),
#  ('D7', 'S1'),
#  ('D7', 'S2'),
#  ('D7', 'S3'),
#  ('D7', 'S4'),
#  ('D7', 'S5'),
#  ('D7', 'S6'),
#  ('D7', 'S7')]

# %%
# python program to demonstrate
# unique combination of two lists
# using zip() and product() of itertools



# import itertools package
import itertools
from itertools import product



# initialize lists
#list_1 = ["d1","d2","d3","d4","d5","d6","d7"]
#list_2 = ["s1","s2","s3","s4","s5","s6","s7"]

list_1 = ["d1","d2","d3","d4","d5","d6","d7"]
list_2 = [1,2,3,4,5,6,7]



# create empty list to store the combinations
unique_combinations = []



# Extract Combination Mapping in two lists
# using zip() + product()
unique_combinations = list(list(zip(list_1, element))
                        for element in product(list_2, repeat = len(list_1)))



# printing unique_combination list
len(unique_combinations)
# Out:
# 823543

# %%
count=0
for i in unique_combinations:
    for j in unique_combinations[i]:
        for k in unique_combinations[j]:
            if(unique_combinations[i][j][k]==2):
                count+=1
print(count)

# Python program to illustrate
# enumerate function in loops
l1 = ["eat", "sleep", "repeat"]

# printing the tuples in object directly
for ele in enumerate(unique_combinations):
    print (ele
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 count=0
#       2 for i in unique_combinations:
# ----> 3     for j in unique_combinations[i]:
#       4         for k in unique_combinations[j]:
#       5             if(unique_combinations[i][j][k]==2):
#
# TypeError: list indices must be integers or slices, not list

# %%
type(unique_combinations)
# Out:
# list

# %%
test=unique_combinations[0:5]

# %%
for i in test:
    print(i)
# Out:
# [('d1', 1), ('d2', 1), ('d3', 1), ('d4', 1), ('d5', 1), ('d6', 1), ('d7', 1)]
# [('d1', 1), ('d2', 1), ('d3', 1), ('d4', 1), ('d5', 1), ('d6', 1), ('d7', 2)]
# [('d1', 1), ('d2', 1), ('d3', 1), ('d4', 1), ('d5', 1), ('d6', 1), ('d7', 3)]
# [('d1', 1), ('d2', 1), ('d3', 1), ('d4', 1), ('d5', 1), ('d6', 1), ('d7', 4)]
# [('d1', 1), ('d2', 1), ('d3', 1), ('d4', 1), ('d5', 1), ('d6', 1), ('d7', 5)]

# %%
for i in test:
    print(i[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 for i,j in test:
#       2     print(i[j])
#
# ValueError: too many values to unpack (expected 2)
